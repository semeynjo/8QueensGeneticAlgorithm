# %%
import random
import numpy as np
import sys

# %%
random.randint(0,7)
# Out:
# 1

# %%
class Queens:
    
    def __init__(self,chrom_length=8):
        self.chrom_length = chrom_length
        
    def make_chrom(self):
        chrom = [random.randint(0,7) for i in range(8)]
        #chrom = random.sample(range(self.chrom_length), self.chrom_length)
        return chrom
    
    def initial_pop(self,pop_size):
        population =[self.make_chrom() for i in range(pop_size)]
        return population
    
    def chrom_score(self, chrom):
        conflicts = 0

        conflicts += abs(len(chrom) - len(np.unique(chrom)))
            
        for i in range(len(chrom)):
            for j in range(len(chrom)):
                if i != j:
                    x = abs(i-j)
                    y = (abs(chrom[i] - chrom[j]))
                    if x == y:
                        conflicts += 1
        return conflicts
    
    def pop_score(self, population, verbose):
        score_list = []
        for chrom in population:
            score_list.append(self.chrom_score(chrom))
            
        tot_score = sum(score_list)
        ave_score = tot_score/len(score_list)
        best = min(score_list)
        if verbose == True:
            print('The total score is {}.\nThe average score is {}.\nThe best score is {}'
                  .format(tot_score, ave_score, best))
        return score_list, best
    
    
    def sort_population(self, population, score_list):
        sort_pop = [x for _,x in sorted(zip(score_list,population))]
        return sort_pop
                                   
    def cross_over(self, chrom1, chrom2):                   
        cross_point = random.randint(1,len(chrom1))
        child1 = chrom1[:cross_point] + chrom2[cross_point:]
        child2 = chrom2[:cross_point] + chrom1[cross_point:]

        if self.chrom_score(child1) < self.chrom_score(child2):
            return child1
        elif self.chrom_score(child1) > self.chrom_score(child2):
            return child2
        else:
            choice = random.randint(1,2)
            if choice == 1:
                return child1
            elif choice == 2: 
                return child2
            
    def shuffle_mutate(self, chrom):
        mutation = random.shuffle(chrom)
        return mutation
    
    def swap_mutate(self, chrom):
        swap = random.sample(range(self.chrom_length), 2)
        chrom[swap[0]], chrom[swap[1]] = chrom[swap[1]], chrom[swap[0]]
        return chrom
    
    def replace_mutate(self, chrom):
        gene = random.randint(0,7)
        chrom[gene] = random.randint(0,7)
        return chrom
    
    def new_pop(self, population, score_list, swap_rate = 0.01, replace_rate = 0.01, shuffle_rate = 0.001):
        mutations = 0
        sort_pop = self.sort_population(population, score_list)
        new_gen = []
        for i in range(0, len(sort_pop), 2):
            
            new_gen.append(self.cross_over(sort_pop[i],sort_pop[-i]))
        
        tot_pop = new_gen + sort_pop[:int(len(sort_pop)/2)]
        
        if random.random() < swap_rate:
            mutations += 1
            for chrom in tot_pop:
                chrom = self.swap_mutate(chrom)
                
        if random.random() < replace_rate:
            mutations += 1
            for chrom in tot_pop:
                chrom = self.replace_mutate(chrom)
        
        if random.random() < shuffle_rate:
            mutations += 1
            for chrom in tot_pop:
                chrom = self.shuffle_mutate(chrom)
        #for chrom in tot_pop:
            #if random.random() < mutation_rate:
                #chrom = self.mutate(chrom)
        
        return tot_pop

# %%
board = Queens()
population = board.initial_pop(100)
score_list, best = board.pop_score(population, verbose=True)
# Out:
# The total score is 1236.
# The average score is 12.36.
# The best score is 5

# %%
next_gen = board.new_pop(population, score_list)
score_list, best = board.pop_score(next_gen, verbose=True)
# Out:
# The total score is 915.
# The average score is 9.15.
# The best score is 5

# %%
next_gen = board.new_pop(next_gen, score_list)
score_list, best = board.pop_score(next_gen, verbose=True)
# Out:
# The total score is 789.
# The average score is 7.89.
# The best score is 4

# %%
board = Queens()
population = board.initial_pop(100)
score_list, best = board.pop_score(population, verbose=True)

next_gen = board.new_pop(population, score_list)
score_list, best = board.pop_score(next_gen, verbose=True)

done = False
epoch = 0
shuffle_rate = 0.001
swap_rate = 0.01
replace_rate = 0.01

while not done:
    print('Epoch:',epoch)
    next_gen = board.new_pop(next_gen, score_list, swap_rate, replace_rate, shuffle_rate)
    score_list, best = board.pop_score(next_gen, verbose=True)
    epoch += 1
    if best == 0:
        done = True
    if epoch%100==0:
        shuffle_rate+=0.001
        swap_rate+=0.01
        replace_rate+=0.01
# Out:
# The total score is 1200.
# The average score is 12.0.
# The best score is 3
# The total score is 939.
# The average score is 9.39.
# The best score is 3
# Epoch: 0
# The total score is 822.
# The average score is 8.22.
# The best score is 3
# Epoch: 1
# The total score is 732.
# The average score is 7.32.
# The best score is 2
# Epoch: 2
# The total score is 643.
# The average score is 6.43.
# The best score is 2
# Epoch: 3
# The total score is 545.
# The average score is 5.45.
# The best score is 2
# Epoch: 4
# The total score is 491.
# The average score is 4.91.
# The best score is 2
# Epoch: 5
# The total score is 484.
# The average score is 4.84.
# The best score is 2
# Epoch: 6
# The total score is 417.
# The average score is 4.17.
# The best score is 2
# Epoch: 7
# The total score is 388.
# The average score is 3.88.
# The best score is 2
# Epoch: 8
# The total score is 362.
# The average score is 3.62.
# The best score is 1
# Epoch: 9
# The total score is 322.
# The average score is 3.22.
# The best score is 1
# Epoch: 10
# The total score is 336.
# The average score is 3.36.
# The best score is 1
# Epoch: 11
# The total score is 255.
# The average score is 2.55.
# The best score is 1
# Epoch: 12
# The total score is 285.
# The average score is 2.85.
# The best score is 1
# Epoch: 13
# The total score is 249.
# The average score is 2.49.
# The best score is 1
# Epoch: 14
# The total score is 211.
# The average score is 2.11.
# The best score is 1
# Epoch: 15
# The total score is 248.
# The average score is 2.48.
# The best score is 1
# Epoch: 16
# The total score is 201.
# The average score is 2.01.
# The best score is 1
# Epoch: 17
# The total score is 185.
# The average score is 1.85.
# The best score is 1
# Epoch: 18
# The total score is 109.
# The average score is 1.09.
# The best score is 1
# Epoch: 19
# The total score is 106.
# The average score is 1.06.
# The best score is 1
# Epoch: 20
# The total score is 107.
# The average score is 1.07.
# The best score is 1
# Epoch: 21
# The total score is 114.
# The average score is 1.14.
# The best score is 1
# Epoch: 22
# The total score is 106.
# The average score is 1.06.
# The best score is 1
# Epoch: 23
# The total score is 104.
# The average score is 1.04.
# The best score is 1
# Epoch: 24
# The total score is 104.
# The average score is 1.04.
# The best score is 1
# Epoch: 25
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 26
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 27
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 28
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 29
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 30
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 31
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 32
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 33
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 34
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 35
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 36
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 37
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 38
# The total score is 518.
# The average score is 5.18.
# The best score is 1
# Epoch: 39
# The total score is 377.
# The average score is 3.77.
# The best score is 1
# Epoch: 40
# The total score is 272.
# The average score is 2.72.
# The best score is 1
# Epoch: 41
# The total score is 222.
# The average score is 2.22.
# The best score is 1
# Epoch: 42
# The total score is 151.
# The average score is 1.51.
# The best score is 1
# Epoch: 43
# The total score is 107.
# The average score is 1.07.
# The best score is 1
# Epoch: 44
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 45
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 46
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 47
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 48
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 49
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 50
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 51
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 52
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 53
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 54
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 55
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 56
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 57
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 58
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 59
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 60
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 61
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 62
# The total score is 508.
# The average score is 5.08.
# The best score is 1
# Epoch: 63
# The total score is 358.
# The average score is 3.58.
# The best score is 1
# Epoch: 64
# The total score is 260.
# The average score is 2.6.
# The best score is 1
# Epoch: 65
# The total score is 199.
# The average score is 1.99.
# The best score is 1
# Epoch: 66
# The total score is 123.
# The average score is 1.23.
# The best score is 1
# Epoch: 67
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 68
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 69
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 70
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 71
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 72
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 73
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 74
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 75
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 76
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 77
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 78
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 79
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 80
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 81
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 82
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 83
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 84
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 85
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 86
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 87
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 88
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 89
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 90
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 91
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 92
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 93
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 94
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 95
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 96
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 97
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 98
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 99
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 100
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 101
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 102
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 103
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 104
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 105
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 106
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 107
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 108
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 109
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 110
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 111
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 112
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 113
# The total score is 474.
# The average score is 4.74.
# The best score is 1
# Epoch: 114
# The total score is 343.
# The average score is 3.43.
# The best score is 1
# Epoch: 115
# The total score is 238.
# The average score is 2.38.
# The best score is 1
# Epoch: 116
# The total score is 149.
# The average score is 1.49.
# The best score is 1
# Epoch: 117
# The total score is 106.
# The average score is 1.06.
# The best score is 1
# Epoch: 118
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 119
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 120
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 121
# The total score is 357.
# The average score is 3.57.
# The best score is 1
# Epoch: 122
# The total score is 422.
# The average score is 4.22.
# The best score is 1
# Epoch: 123
# The total score is 261.
# The average score is 2.61.
# The best score is 1
# Epoch: 124
# The total score is 160.
# The average score is 1.6.
# The best score is 1
# Epoch: 125
# The total score is 104.
# The average score is 1.04.
# The best score is 1
# Epoch: 126
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 127
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 128
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 129
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 130
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 131
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 132
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 133
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 134
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 135
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 136
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 137
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 138
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 139
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 140
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 141
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 142
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 143
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 144
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 145
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 146
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 147
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 148
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 149
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 150
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 151
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 152
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 153
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 154
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 155
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 156
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 157
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 158
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 159
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 160
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 161
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 162
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 163
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 164
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 165
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 166
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 167
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 168
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 169
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 170
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 171
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 172
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 173
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 174
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 175
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 176
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 177
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 178
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 179
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 180
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 181
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 182
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 183
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 184
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 185
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 186
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 187
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 188
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 189
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 190
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 191
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 192
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 193
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 194
# The total score is 478.
# The average score is 4.78.
# The best score is 1
# Epoch: 195
# The total score is 338.
# The average score is 3.38.
# The best score is 1
# Epoch: 196
# The total score is 257.
# The average score is 2.57.
# The best score is 1
# Epoch: 197
# The total score is 197.
# The average score is 1.97.
# The best score is 1
# Epoch: 198
# The total score is 116.
# The average score is 1.16.
# The best score is 1
# Epoch: 199
# The total score is 104.
# The average score is 1.04.
# The best score is 1
# Epoch: 200
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 201
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 202
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 203
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 204
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 205
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 206
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 207
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 208
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 209
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 210
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 211
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 212
# The total score is 338.
# The average score is 3.38.
# The best score is 0

# %%
board = Queens()
population = board.initial_pop(100)
score_list, best = board.pop_score(population, verbose=True)

done = False
epoch = 0
shuffle_rate = 0.001
swap_rate = 0.01
replace_rate = 0.01

while not done:
    print('Epoch:',epoch)
    population = board.new_pop(population, score_list, swap_rate, replace_rate, shuffle_rate)
    score_list, best = board.pop_score(population, verbose=True)
    epoch += 1
    if best == 0:
        print('Done')
        
        done = True
    if epoch%100==0:
        shuffle_rate+=0.001
        swap_rate+=0.01
        replace_rate+=0.01
# Out:
# The total score is 1131.
# The average score is 11.31.
# The best score is 4
# Epoch: 0
# The total score is 892.
# The average score is 8.92.
# The best score is 4
# Epoch: 1
# The total score is 770.
# The average score is 7.7.
# The best score is 3
# Epoch: 2
# The total score is 678.
# The average score is 6.78.
# The best score is 3
# Epoch: 3
# The total score is 601.
# The average score is 6.01.
# The best score is 2
# Epoch: 4
# The total score is 881.
# The average score is 8.81.
# The best score is 1
# Epoch: 5
# The total score is 678.
# The average score is 6.78.
# The best score is 1
# Epoch: 6
# The total score is 586.
# The average score is 5.86.
# The best score is 1
# Epoch: 7
# The total score is 520.
# The average score is 5.2.
# The best score is 1
# Epoch: 8
# The total score is 449.
# The average score is 4.49.
# The best score is 1
# Epoch: 9
# The total score is 391.
# The average score is 3.91.
# The best score is 1
# Epoch: 10
# The total score is 349.
# The average score is 3.49.
# The best score is 1
# Epoch: 11
# The total score is 272.
# The average score is 2.72.
# The best score is 1
# Epoch: 12
# The total score is 269.
# The average score is 2.69.
# The best score is 1
# Epoch: 13
# The total score is 196.
# The average score is 1.96.
# The best score is 1
# Epoch: 14
# The total score is 152.
# The average score is 1.52.
# The best score is 1
# Epoch: 15
# The total score is 182.
# The average score is 1.82.
# The best score is 1
# Epoch: 16
# The total score is 121.
# The average score is 1.21.
# The best score is 1
# Epoch: 17
# The total score is 110.
# The average score is 1.1.
# The best score is 1
# Epoch: 18
# The total score is 103.
# The average score is 1.03.
# The best score is 1
# Epoch: 19
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 20
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 21
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 22
# The total score is 596.
# The average score is 5.96.
# The best score is 1
# Epoch: 23
# The total score is 464.
# The average score is 4.64.
# The best score is 1
# Epoch: 24
# The total score is 374.
# The average score is 3.74.
# The best score is 1
# Epoch: 25
# The total score is 277.
# The average score is 2.77.
# The best score is 1
# Epoch: 26
# The total score is 165.
# The average score is 1.65.
# The best score is 1
# Epoch: 27
# The total score is 105.
# The average score is 1.05.
# The best score is 1
# Epoch: 28
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 29
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 30
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 31
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 32
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 33
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 34
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 35
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 36
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 37
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 38
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 39
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 40
# The total score is 377.
# The average score is 3.77.
# The best score is 1
# Epoch: 41
# The total score is 457.
# The average score is 4.57.
# The best score is 1
# Epoch: 42
# The total score is 303.
# The average score is 3.03.
# The best score is 1
# Epoch: 43
# The total score is 206.
# The average score is 2.06.
# The best score is 1
# Epoch: 44
# The total score is 109.
# The average score is 1.09.
# The best score is 1
# Epoch: 45
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 46
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 47
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 48
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 49
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 50
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 51
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 52
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 53
# The total score is 622.
# The average score is 6.22.
# The best score is 1
# Epoch: 54
# The total score is 488.
# The average score is 4.88.
# The best score is 1
# Epoch: 55
# The total score is 391.
# The average score is 3.91.
# The best score is 1
# Epoch: 56
# The total score is 308.
# The average score is 3.08.
# The best score is 1
# Epoch: 57
# The total score is 202.
# The average score is 2.02.
# The best score is 1
# Epoch: 58
# The total score is 109.
# The average score is 1.09.
# The best score is 1
# Epoch: 59
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 60
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 61
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 62
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 63
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 64
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 65
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 66
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 67
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 68
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 69
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 70
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 71
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 72
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 73
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 74
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 75
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 76
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 77
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 78
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 79
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 80
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 81
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 82
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 83
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 84
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 85
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 86
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 87
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 88
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 89
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 90
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 91
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 92
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 93
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 94
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 95
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 96
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 97
# The total score is 387.
# The average score is 3.87.
# The best score is 1
# Epoch: 98
# The total score is 236.
# The average score is 2.36.
# The best score is 1
# Epoch: 99
# The total score is 131.
# The average score is 1.31.
# The best score is 1
# Epoch: 100
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 101
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 102
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 103
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 104
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 105
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 106
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 107
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 108
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 109
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 110
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 111
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 112
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 113
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 114
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 115
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 116
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 117
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 118
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 119
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 120
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 121
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 122
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 123
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 124
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 125
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 126
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 127
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 128
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 129
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 130
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 131
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 132
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 133
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 134
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 135
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 136
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 137
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 138
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 139
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 140
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 141
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 142
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 143
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 144
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 145
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 146
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 147
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 148
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 149
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 150
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 151
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 152
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 153
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 154
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 155
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 156
# The total score is 369.
# The average score is 3.69.
# The best score is 1
# Epoch: 157
# The total score is 209.
# The average score is 2.09.
# The best score is 1
# Epoch: 158
# The total score is 104.
# The average score is 1.04.
# The best score is 1
# Epoch: 159
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 160
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 161
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 162
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 163
# The total score is 622.
# The average score is 6.22.
# The best score is 1
# Epoch: 164
# The total score is 476.
# The average score is 4.76.
# The best score is 1
# Epoch: 165
# The total score is 385.
# The average score is 3.85.
# The best score is 1
# Epoch: 166
# The total score is 283.
# The average score is 2.83.
# The best score is 1
# Epoch: 167
# The total score is 148.
# The average score is 1.48.
# The best score is 1
# Epoch: 168
# The total score is 101.
# The average score is 1.01.
# The best score is 1
# Epoch: 169
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 170
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 171
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 172
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 173
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 174
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 175
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 176
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 177
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 178
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 179
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 180
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 181
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 182
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 183
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 184
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 185
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 186
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 187
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 188
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 189
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 190
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 191
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 192
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 193
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 194
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 195
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 196
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 197
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 198
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 199
# The total score is 372.
# The average score is 3.72.
# The best score is 1
# Epoch: 200
# The total score is 202.
# The average score is 2.02.
# The best score is 1
# Epoch: 201
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 202
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 203
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 204
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 205
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 206
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 207
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 208
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 209
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 210
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 211
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 212
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 213
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 214
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 215
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 216
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 217
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 218
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 219
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 220
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 221
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 222
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 223
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 224
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 225
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 226
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 227
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 228
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 229
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 230
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 231
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 232
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 233
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 234
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 235
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 236
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 237
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 238
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 239
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 240
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 241
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 242
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 243
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 244
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 245
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 246
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 247
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 248
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 249
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 250
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 251
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 252
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 253
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 254
# The total score is 598.
# The average score is 5.98.
# The best score is 1
# Epoch: 255
# The total score is 435.
# The average score is 4.35.
# The best score is 1
# Epoch: 256
# The total score is 305.
# The average score is 3.05.
# The best score is 1
# Epoch: 257
# The total score is 189.
# The average score is 1.89.
# The best score is 1
# Epoch: 258
# The total score is 106.
# The average score is 1.06.
# The best score is 1
# Epoch: 259
# The total score is 101.
# The average score is 1.01.
# The best score is 1
# Epoch: 260
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 261
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 262
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 263
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 264
# The total score is 618.
# The average score is 6.18.
# The best score is 1
# Epoch: 265
# The total score is 471.
# The average score is 4.71.
# The best score is 1
# Epoch: 266
# The total score is 346.
# The average score is 3.46.
# The best score is 1
# Epoch: 267
# The total score is 246.
# The average score is 2.46.
# The best score is 1
# Epoch: 268
# The total score is 143.
# The average score is 1.43.
# The best score is 1
# Epoch: 269
# The total score is 101.
# The average score is 1.01.
# The best score is 1
# Epoch: 270
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 271
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 272
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 273
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 274
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 275
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 276
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 277
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 278
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 279
# The total score is 634.
# The average score is 6.34.
# The best score is 1
# Epoch: 280
# The total score is 699.
# The average score is 6.99.
# The best score is 2
# Epoch: 281
# The total score is 523.
# The average score is 5.23.
# The best score is 1
# Epoch: 282
# The total score is 405.
# The average score is 4.05.
# The best score is 1
# Epoch: 283
# The total score is 304.
# The average score is 3.04.
# The best score is 1
# Epoch: 284
# The total score is 191.
# The average score is 1.91.
# The best score is 1
# Epoch: 285
# The total score is 105.
# The average score is 1.05.
# The best score is 0
# Done

# %%
board = []
for i in range(8):
    board.append([""] * 8)
    board[i][population[0][i]] = "Q"

# %%
sys.stdout.write("Board:\n")
for j in range(8):
    for i in range(8):
        if board[i][j] == "Q":
            sys.stdout.write("Q ")
        else:
            sys.stdout.write("- ")

    sys.stdout.write("\n")
# Out:
# Board:
# - - - - - Q - -
# - - Q - - - - -
# Q - - - - - Q -
# - - - Q - - - -
# - - - - - - - Q
# - - - - Q - - -
# - Q - - - - - -
# - - - - - - - -
