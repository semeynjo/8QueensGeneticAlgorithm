# %%
import random
import numpy as np
import sys

# %%
class nQueens:
    
    def __init__(self,chrom_length=8):
        '''
        Initializes the board state with a board of chrom_length x chrom_length,
        where chrom_length is the length of the chromosome.
        
        Keyword Arguments:
        chrom_length - length of the chromosome; default is 8 as this is aimed at 
                       solving the 8 queen problem
        '''
        self.chrom_length = chrom_length
      
    
    def make_chrom(self):
        '''
        Uses the chrom_length to create a chromosome.
        '''
        chrom = [random.randint(0,self.chrom_length-1) for i in range(self.chrom_length)]
        #chrom = random.sample(range(self.chrom_length), self.chrom_length)
        return chrom
    
    
    def initial_pop(self,pop_size):
        '''
        Creates a population of chromosomes of length chrom_length.
        '''
        population =[self.make_chrom() for i in range(pop_size)]
        return population
    
    
    def chrom_score(self, chrom):
        '''
        Determines the "score" of the chromosome based on the number of horizontal,
        vertical, and diagonal conflicts of the genes in the chromosome. A lower score is
        better as it means less conflicts.
        '''
        conflicts = 0

        conflicts += abs(len(chrom) - len(np.unique(chrom)))
            
        for i in range(len(chrom)):
            for j in range(len(chrom)):
                if i != j:
                    x = abs(i-j)
                    y = (abs(chrom[i] - chrom[j]))
                    if x == y:
                        conflicts += 1
        return conflicts
    
    
    def pop_score(self, population, verbose = True):
        '''
        Expands chrom_score to an entire population of chromosomes.
        
        Keyword Arguments:
        population - list containing the population of chromosomes to score.
        verbose - allows for tracking of total score, average score, and best score
                  of a population; default is true
        
        Returns:
        score_list - list containing the score for each chromosome in the population
        best - the best score of a chromosome in the population
        '''
        score_list = []
        for chrom in population:
            score_list.append(self.chrom_score(chrom))
            
        tot_score = sum(score_list)
        ave_score = tot_score/len(score_list)
        best = min(score_list)
        if verbose == True:
            print('The total score is {}.\nThe average score is {}.\nThe best score is {}'
                  .format(tot_score, ave_score, best))
            
        return score_list, best
    
    
    def sort_population(self, population, score_list):
        '''
        Sorts the population based on scores; best score to worst score.
        '''
        sort_pop = [x for _,x in sorted(zip(score_list,population))]
        return sort_pop
      
        
    def cross_over(self, chrom1, chrom2):  
        '''
        Performs crossover between two chromosomes at a random crossing point.
        Returns the best child.
        '''
        cross_point = random.randint(1,len(chrom1))
        child1 = chrom1[:cross_point] + chrom2[cross_point:]
        child2 = chrom2[:cross_point] + chrom1[cross_point:]

        if self.chrom_score(child1) < self.chrom_score(child2):
            return child1
        elif self.chrom_score(child1) > self.chrom_score(child2):
            return child2
        else:
            choice = random.randint(1,2)
            if choice == 1:
                return child1
            elif choice == 2: 
                return child2
         
        
    def shuffle_mutate(self, chrom):
        '''
        Mutation that shuffles the entire chromosome.
        '''
        mutation = random.shuffle(chrom)
        return mutation
    
    def swap_mutate(self, chrom):
        '''
        Mutation that swaps two random genes within a chromosome.
        '''
        swap = random.sample(range(self.chrom_length), 2)
        chrom[swap[0]], chrom[swap[1]] = chrom[swap[1]], chrom[swap[0]]
        return chrom
    
    def replace_mutate(self, chrom):
        '''
        Mutation that replaces a random gene with a new random number.
        '''
        gene = random.randint(0,self.chrom_length-1)
        chrom[gene] = random.randint(0,self.chrom_length-1)
        return chrom
    
    
    def new_pop(self, population, score_list, swap_rate = 0.01, replace_rate = 0.01, shuffle_rate = 0.001):
        '''
        Creates the next generation by "breeding" the current population, pairing the best with the worst 
        to ensure variation among the children. Keeps the best half of the current population and combines it 
        with the children to create the next generation.
        
        Keyword Arguments:
        population - list containing the current population
        score_list - list containing the scores for the current population
        swap_rate - rate at which the swap mutation occurs; default 0.01 (1%)
        replace_rate - rate at which the replace mutation occurs; default 0.01 (1%)
        shuffle_rate - rate at which the shuffle mutation occurs; default 0.001 (0.1%)
        
        Returns:
        tot_pop - new population containing the best half of the parents and the 
                  best half of the children
        '''
        mutations = 0
        sort_pop = self.sort_population(population, score_list)
        new_gen = []
        for i in range(0, len(sort_pop), 2):
            
            new_gen.append(self.cross_over(sort_pop[i],sort_pop[-i]))
        
        tot_pop = new_gen + sort_pop[:int(len(sort_pop)/2)]
        
        if random.random() < swap_rate:
            mutations += 1
            for chrom in tot_pop:
                chrom = self.swap_mutate(chrom)
                
        if random.random() < replace_rate:
            mutations += 1
            for chrom in tot_pop:
                chrom = self.replace_mutate(chrom)
        
        if random.random() < shuffle_rate:
            mutations += 1
            for chrom in tot_pop:
                chrom = self.shuffle_mutate(chrom)
        
        return tot_pop

# %%
def main(chrom_length, swap_rate, replace_rate, shuffle_rate, initial_pop_size, verbose):
    
    game = nQueens(chrom_length = chrom_length)
    population = game.initial_pop(pop_size = initial_pop_size)
    score_list, best = game.pop_score(population, verbose=True)
    
    done = False
    epoch = 0

    while not done:
        print('Epoch:',epoch)
        population = game.new_pop(population, score_list, swap_rate = swap_rate, replace_rate = replace_rate, 
                                  shuffle_rate = shuffle_rate)
        score_list, best = game.pop_score(population, verbose = verbose)
        epoch += 1
        if best == 0:
            print('Done')
            sort_final = game.sort_population(population, score_list)
            done = True
        if epoch%100==0:
            shuffle_rate+=0.001
            swap_rate+=0.01
            replace_rate+=0.01
    
    print('\nNumber of epochs to find a solution:',epoch)
    print('A solution to the {} queen problem is:{}'.format(chrom_length, sort_final[0]))
            
    board = []
    for i in range(chrom_length):
        board.append([""] * chrom_length)
        board[i][sort_final[0][i]] = "Q"
        
    sys.stdout.write("Solution:\n")
    for j in range(chrom_length):
        for i in range(chrom_length):
            if board[i][j] == "Q":
                sys.stdout.write("Q ")
            else:
                sys.stdout.write("_ ")

        sys.stdout.write("\n")

# %%
if __name__ == '__main__':
    chrom_length = 8
    swap_rate = 0.01
    replace_rate = 0.01
    shuffle_rate = 0.001
    initial_pop_size = 100
    verbose = True
    main(chrom_length, swap_rate, replace_rate, shuffle_rate, initial_pop_size, verbose)
# Out:
# The total score is 1105.
# The average score is 11.05.
# The best score is 3
# Epoch: 0
# The total score is 839.
# The average score is 8.39.
# The best score is 3
# Epoch: 1
# The total score is 695.
# The average score is 6.95.
# The best score is 3
# Epoch: 2
# The total score is 616.
# The average score is 6.16.
# The best score is 3
# Epoch: 3
# The total score is 542.
# The average score is 5.42.
# The best score is 2
# Epoch: 4
# The total score is 498.
# The average score is 4.98.
# The best score is 2
# Epoch: 5
# The total score is 440.
# The average score is 4.4.
# The best score is 2
# Epoch: 6
# The total score is 428.
# The average score is 4.28.
# The best score is 2
# Epoch: 7
# The total score is 392.
# The average score is 3.92.
# The best score is 2
# Epoch: 8
# The total score is 358.
# The average score is 3.58.
# The best score is 2
# Epoch: 9
# The total score is 332.
# The average score is 3.32.
# The best score is 2
# Epoch: 10
# The total score is 334.
# The average score is 3.34.
# The best score is 2
# Epoch: 11
# The total score is 291.
# The average score is 2.91.
# The best score is 2
# Epoch: 12
# The total score is 246.
# The average score is 2.46.
# The best score is 2
# Epoch: 13
# The total score is 235.
# The average score is 2.35.
# The best score is 2
# Epoch: 14
# The total score is 436.
# The average score is 4.36.
# The best score is 1
# Epoch: 15
# The total score is 314.
# The average score is 3.14.
# The best score is 1
# Epoch: 16
# The total score is 228.
# The average score is 2.28.
# The best score is 1
# Epoch: 17
# The total score is 188.
# The average score is 1.88.
# The best score is 1
# Epoch: 18
# The total score is 177.
# The average score is 1.77.
# The best score is 1
# Epoch: 19
# The total score is 144.
# The average score is 1.44.
# The best score is 1
# Epoch: 20
# The total score is 105.
# The average score is 1.05.
# The best score is 1
# Epoch: 21
# The total score is 104.
# The average score is 1.04.
# The best score is 1
# Epoch: 22
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 23
# The total score is 113.
# The average score is 1.13.
# The best score is 1
# Epoch: 24
# The total score is 104.
# The average score is 1.04.
# The best score is 1
# Epoch: 25
# The total score is 113.
# The average score is 1.13.
# The best score is 1
# Epoch: 26
# The total score is 111.
# The average score is 1.11.
# The best score is 1
# Epoch: 27
# The total score is 123.
# The average score is 1.23.
# The best score is 1
# Epoch: 28
# The total score is 112.
# The average score is 1.12.
# The best score is 1
# Epoch: 29
# The total score is 104.
# The average score is 1.04.
# The best score is 1
# Epoch: 30
# The total score is 102.
# The average score is 1.02.
# The best score is 1
# Epoch: 31
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 32
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 33
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 34
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 35
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 36
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 37
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 38
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 39
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 40
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 41
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 42
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 43
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 44
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 45
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 46
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 47
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 48
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 49
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 50
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 51
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 52
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 53
# The total score is 612.
# The average score is 6.12.
# The best score is 1
# Epoch: 54
# The total score is 490.
# The average score is 4.9.
# The best score is 1
# Epoch: 55
# The total score is 393.
# The average score is 3.93.
# The best score is 1
# Epoch: 56
# The total score is 263.
# The average score is 2.63.
# The best score is 1
# Epoch: 57
# The total score is 160.
# The average score is 1.6.
# The best score is 1
# Epoch: 58
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 59
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 60
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 61
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 62
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 63
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 64
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 65
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 66
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 67
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 68
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 69
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 70
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 71
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 72
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 73
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 74
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 75
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 76
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 77
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 78
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 79
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 80
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 81
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 82
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 83
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 84
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 85
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 86
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 87
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 88
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 89
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 90
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 91
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 92
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 93
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 94
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 95
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 96
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 97
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 98
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 99
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 100
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 101
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 102
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 103
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 104
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 105
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 106
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 107
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 108
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 109
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 110
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 111
# The total score is 359.
# The average score is 3.59.
# The best score is 1
# Epoch: 112
# The total score is 212.
# The average score is 2.12.
# The best score is 1
# Epoch: 113
# The total score is 120.
# The average score is 1.2.
# The best score is 1
# Epoch: 114
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 115
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 116
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 117
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 118
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 119
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 120
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 121
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 122
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 123
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 124
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 125
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 126
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 127
# The total score is 389.
# The average score is 3.89.
# The best score is 1
# Epoch: 128
# The total score is 249.
# The average score is 2.49.
# The best score is 1
# Epoch: 129
# The total score is 150.
# The average score is 1.5.
# The best score is 1
# Epoch: 130
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 131
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 132
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 133
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 134
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 135
# The total score is 608.
# The average score is 6.08.
# The best score is 1
# Epoch: 136
# The total score is 486.
# The average score is 4.86.
# The best score is 1
# Epoch: 137
# The total score is 361.
# The average score is 3.61.
# The best score is 1
# Epoch: 138
# The total score is 243.
# The average score is 2.43.
# The best score is 1
# Epoch: 139
# The total score is 128.
# The average score is 1.28.
# The best score is 1
# Epoch: 140
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 141
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 142
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 143
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 144
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 145
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 146
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 147
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 148
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 149
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 150
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 151
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 152
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 153
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 154
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 155
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 156
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 157
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 158
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 159
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 160
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 161
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 162
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 163
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 164
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 165
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 166
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 167
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 168
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 169
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 170
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 171
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 172
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 173
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 174
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 175
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 176
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 177
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 178
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 179
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 180
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 181
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 182
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 183
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 184
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 185
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 186
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 187
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 188
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 189
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 190
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 191
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 192
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 193
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 194
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 195
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 196
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 197
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 198
# The total score is 353.
# The average score is 3.53.
# The best score is 1
# Epoch: 199
# The total score is 194.
# The average score is 1.94.
# The best score is 1
# Epoch: 200
# The total score is 102.
# The average score is 1.02.
# The best score is 1
# Epoch: 201
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 202
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 203
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 204
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 205
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 206
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 207
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 208
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 209
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 210
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 211
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 212
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 213
# The total score is 388.
# The average score is 3.88.
# The best score is 1
# Epoch: 214
# The total score is 255.
# The average score is 2.55.
# The best score is 1
# Epoch: 215
# The total score is 142.
# The average score is 1.42.
# The best score is 1
# Epoch: 216
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 217
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 218
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 219
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 220
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 221
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 222
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 223
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 224
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 225
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 226
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 227
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 228
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 229
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 230
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 231
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 232
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 233
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 234
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 235
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 236
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 237
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 238
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 239
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 240
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 241
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 242
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 243
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 244
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 245
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 246
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 247
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 248
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 249
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 250
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 251
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 252
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 253
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 254
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 255
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 256
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 257
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 258
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 259
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 260
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 261
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 262
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 263
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 264
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 265
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 266
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 267
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 268
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 269
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 270
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 271
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 272
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 273
# The total score is 1160.
# The average score is 11.6.
# The best score is 1
# Epoch: 274
# The total score is 821.
# The average score is 8.21.
# The best score is 1
# Epoch: 275
# The total score is 660.
# The average score is 6.6.
# The best score is 1
# Epoch: 276
# The total score is 549.
# The average score is 5.49.
# The best score is 1
# Epoch: 277
# The total score is 500.
# The average score is 5.0.
# The best score is 1
# Epoch: 278
# The total score is 488.
# The average score is 4.88.
# The best score is 1
# Epoch: 279
# The total score is 813.
# The average score is 8.13.
# The best score is 3
# Epoch: 280
# The total score is 674.
# The average score is 6.74.
# The best score is 3
# Epoch: 281
# The total score is 576.
# The average score is 5.76.
# The best score is 1
# Epoch: 282
# The total score is 520.
# The average score is 5.2.
# The best score is 1
# Epoch: 283
# The total score is 422.
# The average score is 4.22.
# The best score is 1
# Epoch: 284
# The total score is 362.
# The average score is 3.62.
# The best score is 1
# Epoch: 285
# The total score is 340.
# The average score is 3.4.
# The best score is 1
# Epoch: 286
# The total score is 323.
# The average score is 3.23.
# The best score is 1
# Epoch: 287
# The total score is 263.
# The average score is 2.63.
# The best score is 1
# Epoch: 288
# The total score is 258.
# The average score is 2.58.
# The best score is 1
# Epoch: 289
# The total score is 239.
# The average score is 2.39.
# The best score is 1
# Epoch: 290
# The total score is 211.
# The average score is 2.11.
# The best score is 1
# Epoch: 291
# The total score is 201.
# The average score is 2.01.
# The best score is 1
# Epoch: 292
# The total score is 178.
# The average score is 1.78.
# The best score is 1
# Epoch: 293
# The total score is 138.
# The average score is 1.38.
# The best score is 1
# Epoch: 294
# The total score is 116.
# The average score is 1.16.
# The best score is 1
# Epoch: 295
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 296
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 297
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 298
# The total score is 550.
# The average score is 5.5.
# The best score is 1
# Epoch: 299
# The total score is 373.
# The average score is 3.73.
# The best score is 1
# Epoch: 300
# The total score is 247.
# The average score is 2.47.
# The best score is 1
# Epoch: 301
# The total score is 181.
# The average score is 1.81.
# The best score is 1
# Epoch: 302
# The total score is 109.
# The average score is 1.09.
# The best score is 1
# Epoch: 303
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 304
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 305
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 306
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 307
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 308
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 309
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 310
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 311
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 312
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 313
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 314
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 315
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 316
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 317
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 318
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 319
# The total score is 397.
# The average score is 3.97.
# The best score is 1
# Epoch: 320
# The total score is 224.
# The average score is 2.24.
# The best score is 1
# Epoch: 321
# The total score is 120.
# The average score is 1.2.
# The best score is 1
# Epoch: 322
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 323
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 324
# The total score is 360.
# The average score is 3.6.
# The best score is 1
# Epoch: 325
# The total score is 638.
# The average score is 6.38.
# The best score is 1
# Epoch: 326
# The total score is 501.
# The average score is 5.01.
# The best score is 1
# Epoch: 327
# The total score is 338.
# The average score is 3.38.
# The best score is 1
# Epoch: 328
# The total score is 659.
# The average score is 6.59.
# The best score is 1
# Epoch: 329
# The total score is 500.
# The average score is 5.0.
# The best score is 1
# Epoch: 330
# The total score is 385.
# The average score is 3.85.
# The best score is 1
# Epoch: 331
# The total score is 289.
# The average score is 2.89.
# The best score is 1
# Epoch: 332
# The total score is 209.
# The average score is 2.09.
# The best score is 1
# Epoch: 333
# The total score is 146.
# The average score is 1.46.
# The best score is 1
# Epoch: 334
# The total score is 120.
# The average score is 1.2.
# The best score is 1
# Epoch: 335
# The total score is 372.
# The average score is 3.72.
# The best score is 1
# Epoch: 336
# The total score is 476.
# The average score is 4.76.
# The best score is 1
# Epoch: 337
# The total score is 298.
# The average score is 2.98.
# The best score is 1
# Epoch: 338
# The total score is 184.
# The average score is 1.84.
# The best score is 1
# Epoch: 339
# The total score is 112.
# The average score is 1.12.
# The best score is 1
# Epoch: 340
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 341
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 342
# The total score is 101.
# The average score is 1.01.
# The best score is 1
# Epoch: 343
# The total score is 106.
# The average score is 1.06.
# The best score is 1
# Epoch: 344
# The total score is 101.
# The average score is 1.01.
# The best score is 1
# Epoch: 345
# The total score is 109.
# The average score is 1.09.
# The best score is 1
# Epoch: 346
# The total score is 105.
# The average score is 1.05.
# The best score is 1
# Epoch: 347
# The total score is 101.
# The average score is 1.01.
# The best score is 1
# Epoch: 348
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 349
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 350
# The total score is 367.
# The average score is 3.67.
# The best score is 1
# Epoch: 351
# The total score is 210.
# The average score is 2.1.
# The best score is 1
# Epoch: 352
# The total score is 116.
# The average score is 1.16.
# The best score is 1
# Epoch: 353
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 354
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 355
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 356
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 357
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 358
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 359
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 360
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 361
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 362
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 363
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 364
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 365
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 366
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 367
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 368
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 369
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 370
# The total score is 358.
# The average score is 3.58.
# The best score is 1
# Epoch: 371
# The total score is 193.
# The average score is 1.93.
# The best score is 1
# Epoch: 372
# The total score is 106.
# The average score is 1.06.
# The best score is 1
# Epoch: 373
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 374
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 375
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 376
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 377
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 378
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 379
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 380
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 381
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 382
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 383
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 384
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 385
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 386
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 387
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 388
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 389
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 390
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 391
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 392
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 393
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 394
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 395
# The total score is 386.
# The average score is 3.86.
# The best score is 1
# Epoch: 396
# The total score is 229.
# The average score is 2.29.
# The best score is 1
# Epoch: 397
# The total score is 135.
# The average score is 1.35.
# The best score is 1
# Epoch: 398
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 399
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 400
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 401
# The total score is 376.
# The average score is 3.76.
# The best score is 1
# Epoch: 402
# The total score is 230.
# The average score is 2.3.
# The best score is 1
# Epoch: 403
# The total score is 127.
# The average score is 1.27.
# The best score is 1
# Epoch: 404
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 405
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 406
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 407
# The total score is 364.
# The average score is 3.64.
# The best score is 1
# Epoch: 408
# The total score is 214.
# The average score is 2.14.
# The best score is 1
# Epoch: 409
# The total score is 111.
# The average score is 1.11.
# The best score is 1
# Epoch: 410
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 411
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 412
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 413
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 414
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 415
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 416
# The total score is 365.
# The average score is 3.65.
# The best score is 1
# Epoch: 417
# The total score is 417.
# The average score is 4.17.
# The best score is 1
# Epoch: 418
# The total score is 266.
# The average score is 2.66.
# The best score is 1
# Epoch: 419
# The total score is 171.
# The average score is 1.71.
# The best score is 1
# Epoch: 420
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 421
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 422
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 423
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 424
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 425
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 426
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 427
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 428
# The total score is 366.
# The average score is 3.66.
# The best score is 1
# Epoch: 429
# The total score is 225.
# The average score is 2.25.
# The best score is 1
# Epoch: 430
# The total score is 115.
# The average score is 1.15.
# The best score is 1
# Epoch: 431
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 432
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 433
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 434
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 435
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 436
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 437
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 438
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 439
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 440
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 441
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 442
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 443
# The total score is 588.
# The average score is 5.88.
# The best score is 1
# Epoch: 444
# The total score is 400.
# The average score is 4.0.
# The best score is 1
# Epoch: 445
# The total score is 268.
# The average score is 2.68.
# The best score is 1
# Epoch: 446
# The total score is 455.
# The average score is 4.55.
# The best score is 1
# Epoch: 447
# The total score is 271.
# The average score is 2.71.
# The best score is 1
# Epoch: 448
# The total score is 180.
# The average score is 1.8.
# The best score is 1
# Epoch: 449
# The total score is 130.
# The average score is 1.3.
# The best score is 1
# Epoch: 450
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 451
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 452
# The total score is 520.
# The average score is 5.2.
# The best score is 1
# Epoch: 453
# The total score is 363.
# The average score is 3.63.
# The best score is 1
# Epoch: 454
# The total score is 1047.
# The average score is 10.47.
# The best score is 3
# Epoch: 455
# The total score is 780.
# The average score is 7.8.
# The best score is 3
# Epoch: 456
# The total score is 690.
# The average score is 6.9.
# The best score is 3
# Epoch: 457
# The total score is 621.
# The average score is 6.21.
# The best score is 2
# Epoch: 458
# The total score is 583.
# The average score is 5.83.
# The best score is 2
# Epoch: 459
# The total score is 494.
# The average score is 4.94.
# The best score is 2
# Epoch: 460
# The total score is 446.
# The average score is 4.46.
# The best score is 2
# Epoch: 461
# The total score is 415.
# The average score is 4.15.
# The best score is 1
# Epoch: 462
# The total score is 399.
# The average score is 3.99.
# The best score is 1
# Epoch: 463
# The total score is 355.
# The average score is 3.55.
# The best score is 1
# Epoch: 464
# The total score is 307.
# The average score is 3.07.
# The best score is 1
# Epoch: 465
# The total score is 273.
# The average score is 2.73.
# The best score is 1
# Epoch: 466
# The total score is 209.
# The average score is 2.09.
# The best score is 1
# Epoch: 467
# The total score is 208.
# The average score is 2.08.
# The best score is 1
# Epoch: 468
# The total score is 208.
# The average score is 2.08.
# The best score is 1
# Epoch: 469
# The total score is 173.
# The average score is 1.73.
# The best score is 1
# Epoch: 470
# The total score is 162.
# The average score is 1.62.
# The best score is 1
# Epoch: 471
# The total score is 148.
# The average score is 1.48.
# The best score is 1
# Epoch: 472
# The total score is 107.
# The average score is 1.07.
# The best score is 1
# Epoch: 473
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 474
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 475
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 476
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 477
# The total score is 100.
# The average score is 1.0.
# The best score is 1
# Epoch: 478
# The total score is 369.
# The average score is 3.69.
# The best score is 0
# Done
#
# Number of epochs to find a solution: 479
# A solution to the 8 queen problem is:[1, 6, 4, 7, 0, 3, 5, 2]
# Solution:
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
